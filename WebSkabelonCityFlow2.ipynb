# %% [markdown]
# importer de nødvendige moduler

# %%
import requests
import json

# %% [markdown]
# lav en post-request til https://api.cityflow.live/users/login

# %%
url="https://api.cityflow.live/users/login"
logindata={'email':'thorwulf@hotmail.com', 'password':'d5pljrtr!'}
type(logindata)
retVal=requests.post(url, data=json.dumps(logindata))

# %%
print(retVal.status_code)
# Out:
# 400

# %% [markdown]
# lav en get-request der henter listen af devices

# %%
mytoken="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6NTQ5LCJpYXQiOjE2MzY1MzY0NDAsImV4cCI6MTYzNjYyMjg0MH0.KXcM1FhxwUNQwprCtGIgXw8YefDsimAOK9IOZ1wEcRw"

# %%
headers = {'Authorization': "Bearer "+ mytoken}

# %% [markdown]
# lav en get-request der henter de nyeste målinger https://api.cityflow.live/measurements/latest
# Du gemmer resultatet af din request i en variabel som så er af type response-objekt.

# %%
url="https://api.cityflow.live/measurements/latest"

measurems=requests.get(url, headers=headers)

# %% [markdown]
# Du henter nu en datastruktur ud af response-objektet (response.json())
# Undersøg strukturen af de returnerede data så du kan nå ind til listen af målinger
# Du får nemlig noget a la {   '150': [   {   'aPS': 0.69,
#                    'b': 100,

# %%
type(measurems)
msm=measurems.json()

# %% [markdown]
# Nu kan du hente pretty-print så dit resultat står pænt

# %%
print(type(msm))
# Out:
# <class 'dict'>

# %%
import pprint as pp
#dineMeasures=[]
pp.pprint(msm)
# Out:
# {'150': [{'aPS': 0.72,
#           'b': 100,
#           'device_id': 'e00fce68f5c71b9827949e46',
#           'h': 93.32,
#           'l': 2187.65,
#           'location': '196',
#           'mP1': 13.22,
#           'mP2': 15.95,
#           'mP4': 17.55,
#           'mPX': 17.87,
#           'nA': 60.25,
#           'nMa': 63.05,
#           'nMi': 53.13,
#           'nP1': 103.09,
#           'nP2': 105.35,
#           'nP4': 105.78,
#           'nPX': 105.86,
#           'nS': 1.82,
#           'p': 1010.59,
#           'rA': 871.7,
#           'rMa': 947,
#           'rMi': 341,
#           'rS': 152.48,
#           't': 12.41,
#           'time': '2021-11-10T09:51:10.000Z'},
#          {'aPS': 0.71,
#           'b': 100,
#           'device_id': 'e00fce68f09429bef0f72416',
#           'h': 90.99,
#           'l': 998.52,
#           'location': '218',
#           'mP1': 7.27,
#           'mP2': 8.43,
#           'mP4': 9.02,
#           'mPX': 9.14,
#           'nA': 63.38,
#           'nMa': 65.73,
#           'nMi': 52.45,
#           'nP1': 57.09,
#           'nP2': 57.99,
#           'nP4': 58.16,
#           'nPX': 58.19,
#           'nS': 3.9,
#           'p': 1016.45,
#           'rA': 15.91,
#           'rMa': 103,
#           'rMi': -22,
#           'rS': 44.01,
#           't': 12.35,
#           'time': '2021-11-10T09:30:46.000Z'},
#          {'aPS': 0.72,
#           'b': 100,
#           'device_id': 'e00fce68df0c76405e31ec8d',
#           'h': 91.79,
#           'l': 2858.21,
#           'location': '191',
#           'mP1': 9.65,
#           'mP2': 12.35,
#           'mP4': 14.08,
#           'mPX': 14.43,
#           'nA': 64.58,
#           'nMa': 71.75,
#           'nMi': 54.67,
#           'nP1': 74.53,
#           'nP2': 76.88,
#           'nP4': 77.34,
#           'nPX': 77.42,
#           'nS': 4.85,
#           'p': 1017.74,
#           'rA': -228.05,
#           'rMa': -59,
#           'rMi': -502,
#           'rS': 169.85,
#           't': 12.61,
#           'time': '2021-11-10T09:32:10.000Z'},
#          {'aPS': 0.75,
#           'b': 100,
#           'device_id': 'e00fce68d635da0a977bde3a',
#           'h': 87.52,
#           'l': 1158.19,
#           'location': '187',
#           'mP1': 6.28,
#           'mP2': 8,
#           'mP4': 9.1,
#           'mPX': 9.32,
#           'nA': 66.59,
#           'nMa': 66.9,
#           'nMi': 64.63,
#           'nP1': 48.54,
#           'nP2': 50.04,
#           'nP4': 50.33,
#           'nPX': 50.38,
#           'nS': 0.61,
#           'p': 1020.08,
#           'rA': -255.13,
#           'rMa': -211,
#           'rMi': -268,
#           'rS': 14.71,
#           't': 12.62,
#           'time': '2021-11-10T09:32:59.000Z'},
#          {'aPS': 0.72,
#           'b': 100,
#           'device_id': 'e00fce68d0c093ee80798014',
#           'h': 90.75,
#           'l': 1704.77,
#           'location': '195',
#           'mP1': 11.12,
#           'mP2': 15.31,
#           'mP4': 18.19,
#           'mPX': 18.76,
#           'nA': 63.11,
#           'nMa': 64.97,
#           'nMi': 48.43,
#           'nP1': 84.82,
#           'nP2': 88.51,
#           'nP4': 89.23,
#           'nPX': 89.34,
#           'nS': 3.34,
#           'p': 1018.87,
#           'rA': 331.31,
#           'rMa': 365,
#           'rMi': 30,
#           'rS': 63.84,
#           't': 12.46,
#           'time': '2021-11-10T09:33:12.000Z'},
#          {'aPS': 0.53,
#           'b': 100,
#           'device_id': 'e00fce68c93a961932e67b35',
#           'h': 90.73,
#           'l': 1268.69,
#           'location': '189',
#           'mP1': 7.76,
#           'mP2': 8.47,
#           'mP4': 8.69,
#           'mPX': 8.73,
#           'nA': 68.34,
#           'nMa': 68.36,
#           'nMi': 66.65,
#           'nP1': 61.47,
#           'nP2': 61.91,
#           'nP4': 61.99,
#           'nPX': 62.01,
#           'nS': 0.21,
#           'p': 1014.1,
#           'rA': 135.93,
#           'rMa': 154,
#           'rMi': 51,
#           'rS': 9.29,
#           't': 12.48,
#           'time': '2021-11-10T09:38:29.000Z'},
#          {'aPS': 0.82,
#           'b': 100,
#           'device_id': 'e00fce68c573b4acca2089ce',
#           'h': 87.46,
#           'l': 1149.73,
#           'location': '216',
#           'mP1': 6.73,
#           'mP2': 8.68,
#           'mP4': 9.95,
#           'mPX': 10.2,
#           'nA': 54.86,
#           'nMa': 57.03,
#           'nMi': 45.23,
#           'nP1': 51.82,
#           'nP2': 53.61,
#           'nP4': 53.89,
#           'nPX': 53.94,
#           'nS': 1.49,
#           'p': 1018.4,
#           'rA': -15.01,
#           'rMa': -2,
#           'rMi': -33,
#           'rS': 4.22,
#           't': 12.79,
#           'time': '2021-11-10T09:33:22.000Z'},
#          {'aPS': 0.69,
#           'b': 100,
#           'device_id': 'e00fce68c2e23416be935b90',
#           'h': 94.5,
#           'l': 1819.74,
#           'location': '192',
#           'mP1': 33.79,
#           'mP2': 43.55,
#           'mP4': 49.87,
#           'mPX': 51.14,
#           'nA': 68.69,
#           'nMa': 69.05,
#           'nMi': 58.04,
#           'nP1': 260.81,
#           'nP2': 269.15,
#           'nP4': 270.76,
#           'nPX': 271.01,
#           'nS': 1.41,
#           'p': 1006.65,
#           'rA': 1260.76,
#           'rMa': 1327,
#           'rMi': 628,
#           'rS': 131.11,
#           't': 15.36,
#           'time': '2021-09-27T08:59:30.000Z'},
#          {'aPS': 0.55,
#           'b': 100,
#           'device_id': 'e00fce68a442f664f35881bc',
#           'h': 95.47,
#           'l': 2140.11,
#           'location': '188',
#           'mP1': 9.26,
#           'mP2': 10.01,
#           'mP4': 10.18,
#           'mPX': 10.21,
#           'nA': 59.82,
#           'nMa': 61.47,
#           'nMi': 47.49,
#           'nP1': 73.5,
#           'nP2': 73.93,
#           'nP4': 74,
#           'nPX': 74.02,
#           'nS': 2.94,
#           'p': 1013.68,
#           'rA': 13.76,
#           'rMa': 41,
#           'rMi': -17,
#           'rS': 11.46,
#           't': 11.8,
#           'time': '2021-11-10T09:31:01.000Z'},
#          {'aPS': 0.92,
#           'b': 100,
#           'device_id': 'e00fce689f02a96799f34fc2',
#           'h': 88.6,
#           'l': 1518.69,
#           'location': '190',
#           'mP1': 5.94,
#           'mP2': 8.79,
#           'mP4': 10.82,
#           'mPX': 11.23,
#           'nA': 53.11,
#           'nMa': 53.13,
#           'nMi': 50.23,
#           'nP1': 44.65,
#           'nP2': 47.26,
#           'nP4': 47.77,
#           'nPX': 47.85,
#           'nS': 0.21,
#           'p': 1018.09,
#           'rA': 121.62,
#           'rMa': 128,
#           'rMi': 37,
#           'rS': 19.57,
#           't': 13.23,
#           'time': '2021-11-10T09:31:01.000Z'},
#          {'aPS': 0.57,
#           'b': 100,
#           'device_id': 'e00fce68870bfda1190b54f0',
#           'h': 87.54,
#           'l': 2054.4,
#           'location': '193',
#           'mP1': 8.19,
#           'mP2': 8.91,
#           'mP4': 9.11,
#           'mPX': 9.15,
#           'nA': 66.35,
#           'nMa': 66.4,
#           'nMi': 63.21,
#           'nP1': 64.93,
#           'nP2': 65.37,
#           'nP4': 65.44,
#           'nPX': 65.46,
#           'nS': 0.36,
#           'p': 1019.33,
#           'rA': 317.53,
#           'rMa': 344,
#           'rMi': 252,
#           'rS': 5.82,
#           't': 12.73,
#           'time': '2021-11-10T09:29:00.000Z'},
#          {'aPS': 0.56,
#           'b': 100,
#           'device_id': 'e00fce687e301675c8bb9810',
#           'h': 88.12,
#           'l': 1023.58,
#           'location': '194',
#           'mP1': 8.66,
#           'mP2': 9.93,
#           'mP4': 10.56,
#           'mPX': 10.68,
#           'nA': 64.34,
#           'nMa': 68.22,
#           'nMi': 54.45,
#           'nP1': 68.12,
#           'nP2': 69.09,
#           'nP4': 69.27,
#           'nPX': 69.3,
#           'nS': 3.32,
#           'p': 1019.01,
#           'rA': 38.93,
#           'rMa': 144,
#           'rMi': 22,
#           'rS': 20.53,
#           't': 12.55,
#           'time': '2021-11-10T09:31:05.000Z'},
#          {'aPS': 0.6,
#           'b': 100,
#           'device_id': 'e00fce687aad43f3328cc46c',
#           'h': 91.2,
#           'l': 1406.04,
#           'location': '206',
#           'mP1': 8.84,
#           'mP2': 11.61,
#           'mP4': 13.44,
#           'mPX': 13.81,
#           'nA': 58.99,
#           'nMa': 63.21,
#           'nMi': 41.21,
#           'nP1': 67.99,
#           'nP2': 70.44,
#           'nP4': 70.92,
#           'nPX': 71,
#           'nS': 4.04,
#           'p': 1012.52,
#           'rA': 105.7,
#           'rMa': 165,
#           'rMi': 41,
#           'rS': 47.96,
#           't': 12.17,
#           'time': '2021-11-10T09:33:46.000Z'},
#          {'aPS': 0.4,
#           'b': 100,
#           'device_id': 'e00fce686bcd3d47f3b06b01',
#           'h': 92.78,
#           'l': 1764.36,
#           'location': '202',
#           'mP1': 4.27,
#           'mP2': 4.52,
#           'mP4': 4.52,
#           'mPX': 4.52,
#           'nA': 65.79,
#           'nMa': 68.18,
#           'nMi': 48.65,
#           'nP1': 34.01,
#           'nP2': 34.11,
#           'nP4': 34.12,
#           'nPX': 34.13,
#           'nS': 5.1,
#           'p': 1013.13,
#           'rA': -153.18,
#           'rMa': 100,
#           'rMi': -206,
#           'rS': 108.29,
#           't': 12.41,
#           'time': '2021-11-10T09:30:51.000Z'},
#          {'aPS': 1.63,
#           'b': 100,
#           'device_id': 'e00fce683182b4876452e2c7',
#           'h': 90.38,
#           'l': 1464.41,
#           'location': '207',
#           'mP1': 0,
#           'mP2': 0,
#           'mP4': 0,
#           'mPX': 0,
#           'nA': 64.75,
#           'nMa': 67.51,
#           'nMi': 55.59,
#           'nP1': 0,
#           'nP2': 0,
#           'nP4': 0,
#           'nPX': 0,
#           'nS': 2.6,
#           'p': 1017.87,
#           'rA': 257.59,
#           'rMa': 373,
#           'rMi': 65,
#           'rS': 86.39,
#           't': 12.69,
#           'time': '2021-11-10T09:31:01.000Z'},
#          {'aPS': 0.47,
#           'b': 71.7,
#           'device_id': 'e00fce682d91dccdcbc76092',
#           'h': 45.05,
#           'l': 72.47,
#           'location': '208',
#           'mP1': 0.61,
#           'mP2': 0.64,
#           'mP4': 0.64,
#           'mPX': 0.64,
#           'nA': 56.27,
#           'nMa': 57.27,
#           'nMi': 42.63,
#           'nP1': 4.82,
#           'nP2': 4.83,
#           'nP4': 4.83,
#           'nPX': 4.83,
#           'nS': 2.22,
#           'p': 1011.94,
#           'rA': 76.12,
#           'rMa': 94,
#           'rMi': 1,
#           'rS': 31.68,
#           't': 28.45,
#           'time': '2021-08-12T10:54:34.000Z'},
#          {'aPS': 0.78,
#           'b': -1,
#           'device_id': 'e00fce680baad81ffe68b9b3',
#           'h': 87.21,
#           'l': 934.05,
#           'location': '217',
#           'mP1': 9.13,
#           'mP2': 12.58,
#           'mP4': 14.95,
#           'mPX': 15.43,
#           'nA': 59.39,
#           'nMa': 60.52,
#           'nMi': 53.75,
#           'nP1': 69.52,
#           'nP2': 72.65,
#           'nP4': 73.26,
#           'nPX': 73.36,
#           'nS': 1.79,
#           'p': 1018.19,
#           'rA': 458.53,
#           'rMa': 557,
#           'rMi': 183,
#           'rS': 142.1,
#           't': 12.56,
#           'time': '2021-11-10T09:41:23.000Z'},
#          {'aPS': 0.72,
#           'b': 100,
#           'device_id': 'e00fce68071a3011cedc95f2',
#           'h': 92.77,
#           'l': 1915.45,
#           'location': '204',
#           'mP1': 1.65,
#           'mP2': 2.22,
#           'mP4': 2.61,
#           'mPX': 2.69,
#           'nA': 70.87,
#           'nMa': 78.12,
#           'nMi': 62.92,
#           'nP1': 12.66,
#           'nP2': 13.16,
#           'nP4': 13.26,
#           'nPX': 13.27,
#           'nS': 3.95,
#           'p': 1018.63,
#           'rA': -272.6,
#           'rMa': -166,
#           'rMi': -430,
#           'rS': 41.02,
#           't': 12.59,
#           'time': '2021-11-10T09:29:13.000Z'}]}

# %% [markdown]
# Nu looper du igennem din liste af målinger vha et for-loop

# %%
for item in dineMeasures:
    pp.pprint(item)

# %% [markdown]
# Nu skal du åbne til din mongo-database

# %%
import pymongo

client=pymongo.MongoClient("mongodb://<ip-adresse>:27017/<din-database")
db = client.test
